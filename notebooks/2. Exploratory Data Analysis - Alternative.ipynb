# %% [markdown]
# # Executive Summary
#
# This notebook will attempt to answer the following research question:
#
#     What's money got to do with it?

# %% [markdown]
# ## PLANNING
#
# - [X] Planning
#     - [X] import libraries/packages
#     - [X] configure notebook environment
#     - [X] define helper functions
# - [X] Acquire data
#     - [X] get PEIMS financial data
#     - [X] get STAAR performance data
# - [X] Prepare the data
#     - [X] prepare PEIMS data
#         - [X] get rid of unwanted columns
#         - [x] get rid of NaNs
#     - [X] prepare STAAR data
#         - [X] get rid of duplicates
#         - [X] get rid of unwanted columns
#         - [X] get rid of NaNs
#         - [X] create new columns
#         - [X] merge two datasets together
# - [ ] Explore the data
#     - [ ] examine for multicollinearity and determine truly independent variables
#     - [ ] get to know the master dataset
#     - [ ] feature engineering
# - [ ] Modeling
#     - [ ] create, fit, use XGBoost
#     - [ ] gridsearch
#     - [ ] retrain model using best hyperparameters
#     - [ ] extract feature importances

# %%
# for manipulating dataframes
import pandas as pd
import numpy as np

# For hypothesis testing
from scipy import stats
from scipy.stats import shapiro
from scipy.stats import mannwhitneyu

# For data preparation
from sklearn.model_selection import train_test_split

# For modeling
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from xgboost import plot_importance

# for visualizations
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# to print out all the outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

ALPHA = 0.05
mannwhitneyu_same = []
mannwhitneyu_diff = []

# %%
def get_values(df, columns):
    """
    Take a dataframe and a list of columns and
    returns the value counts for the columns.
    """
    for column in columns:
        print(column)
        print('=====================================')
        print(df[column].value_counts(dropna=False))
        print('\n')

def show_values(df, param):
    if param == 'all':
        get_values(df, df.columns)
    else:
        get_values(df, param)

# %%
def viz_correlation(df, graph_title, *cols):
     
    dfx = df[list(cols)]
    
    # Use the default Pearson for continuous variables
    corr_matrix = dfx.corr(method ='pearson')

    # Setup
    fig, ax = plt.subplots(figsize=(16,8))

    # vmin and vmax control the range of the colormap
    sns.heatmap(corr_matrix, cmap='RdBu', annot=True, fmt='.2f',
               vmin=-1, vmax=1)

    plt.title(graph_title)

    # Add tight_layout to ensure the labels don't get cut off
    plt.tight_layout()
    plt.show()

# %%
def viz_scatter(df, graph_title, col1, col2):
    plt.figure(figsize=(16, 8))
    plt.scatter(df[col1], df[col2], alpha=0.5)
    plt.xlabel(col1) #x label
    plt.ylabel(col2) #y label
    plt.title(graph_title)
    plt.show()

# %%
def viz_pairplot(df, graph_title, *cols):
     
    dfx = df[list(cols)]
    plt.figure(figsize=(16, 8))
    sns.pairplot(dfx)
    plt.title(graph_title)
    plt.show()

# %%
def loop_levene(df1, df2):
    for column in df1.columns:
        result = stats.levene(df1[column], df2[column])[1]
        if result > ALPHA:
            interpretation = 'insignificant - HOMOGENOUS'
        else:
            interpretation = 'significant - HETEROGENOUS'
        print(result, '-', column, ' - ', interpretation)

# %%
def loop_shapiro(df):
    for column in df.columns:
        statistic, result = shapiro(df[column])
        if result > ALPHA:
            interpretation = 'insignificant - NORMAL'
        else:
            interpretation = 'significant - ABNORMAL'
        print(result, '-', column, ' - ', interpretation)

# %%
def loop_ttest(df1, df2):
    for column in df1.columns:
        result = stats.ttest_ind(df1[column], df2[column])[1]
        if result > ALPHA:
            interpretation = 'insignificant - SAME'
        else:
            interpretation = 'significant - DIFFERENT'
        print(result, '-', column, ' - ', interpretation)

# %%
def loop_mannwhitney(df1, df2):

    for column in df1.columns:
        stat, p = mannwhitneyu(df1[column], df2[column])

        if p > ALPHA:
            interpretation = 'SAME (fail to reject H0)'
            print('Statistics=%.3f, p=%.3f' % (stat, p) + ' - ' + column + ' - ' + interpretation)
            mannwhitneyu_same.append(column)
        else:
            interpretation = 'DIFFERENT (reject H0)'
            print('Statistics=%.3f, p=%.3f' % (stat, p) + ' - ' + column + ' - ' + interpretation)
            mannwhitneyu_diff.append(column)

# %%
def viz_boxplot(df, col1, col2, graph_title):
    plt.figure(figsize=(16, 8))
    sns.boxplot(x = col1, y = col2, data = df)
    plt.title(graph_title)
    plt.show()

# %%
def viz_violin(df, col1, col2, graph_title):
    plt.figure(figsize=(16, 8))
    sns.violinplot(x = col1, y = col2, data = df)
    plt.title(graph_title)
    plt.show()

# %%
def my_plot_importance(booster, figsize, **kwargs): 
    fig, ax = plt.subplots(1,1,figsize=figsize)
    
    return plot_importance(booster=booster, ax=ax, **kwargs)

# %% [markdown]
# ## ACQUIRE DATA

# %%
# Get the PEIMS and STAAR datasets
ethnic = pd.read_csv('../data/inter/clean_ethnic_2019.csv')
staar = pd.read_csv('../data/inter/clean_staar_2019.csv')
peims = pd.read_csv('../data/inter/clean_peims_2019.csv')

# %%
ethnic.head()
staar.head()
peims.head()
# Out:
#    District  Percentage of Non-White Students
# 0      1902                          0.145315
# 1      1903                          0.211415
# 2      1904                          0.213158
# 3      1906                          0.268657
# 4      1907                          0.717973
#    District  Total Number of Students  Total Number of Passing Students
# 0      1902                       932                               842
# 1      1903                      1991                              1651
# 2      1904                      1365                              1064
# 3      1906                       569                               420
# 4      1907                      5497                              3274
#    District   Payroll  Professional & Contracted  Supplies & Materials  \
# 0      1902   6025217                    1075904                648206
# 1      1903   9093950                    1514689                784631
# 2      1904   6659596                     927209                937810
# 3      1906   3134475                     373513                408024
# 4      1907  25587063                    5603896               4134969
#
#    Other Operating  Instruction & Transfer  Instructional Resource Media  \
# 0           809559                 4649118                         66490
# 1           303052                 7043892                        117860
# 2           278109                 4611747                         51126
# 3           105878                 2087166                         19990
# 4          1048416                18807861                        167823
#
#    Curriculum/Staff Development  Instructional Leadership  \
# 0                          4986                    270353
# 1                         33175                     66374
# 2                        157830                         0
# 3                             0                      7905
# 4                        535649                   1033275
#
#    Campus Administration  Guidance & Counseling  Social Work  Health Services  \
# 0                 306385                 998314            0            37882
# 1                 574699                 202086            0            33657
# 2                 466345                 199338            0           102385
# 3                 379101                  75235            0            40628
# 4                2201907                1443630       170074           208736
#
#    Transportation  Food Service  Extracurricular  General Administration  \
# 0          293070        287406           413755                  284553
# 1          422887        630202           598484                  558948
# 2           38800        411195           754465                  539512
# 3          148301        257465           210240                  201520
# 4         1442619       2071781          1422648                 1287489
#
#    Plant Maintenance/Operation  Security & Monitoring  Data Processing  \
# 0                       773085                      0           173489
# 1                      1248908                  13530           151120
# 2                      1014501                  45482           409998
# 3                       465549                  10415           118375
# 4                      3937087                 242658          1006175
#
#    Community Services  Regular Program  Gifted & Talented Program  \
# 0                   0          2778638                       3968
# 1                 500          5313722                         93
# 2                   0          3945494                      10154
# 3                   0          1499301                      14498
# 4              394932         15527277                      39671
#
#    Career & Technology Program  Students with Disabilities  \
# 0                       251350                     3005575
# 1                       852319                     1028587
# 2                       552217                      726827
# 3                       164641                      447072
# 4                      1625090                     2422707
#
#    State Compensatory Education  Bilingual Program  High School Allotment  \
# 0                        273747               9599                  40285
# 1                        799037                  0                 101243
# 2                        377013                  0                  59567
# 3                        402415               2706                  48748
# 4                       3147717             231026                 302531
#
#     Pre-K  Athletics Program  Undistributed Program  \
# 0   32890             304174                1858660
# 1       0             339045                3262276
# 2  114404             571388                2445660
# 3   29920                  0                1412589
# 4  923035            1214433               10940857
#
#    Total Program Expenditures  Other Uses
# 0                     8558886       48633
# 1                    11696322      102465
# 2                     8802724         481
# 3                     4021890       53786
# 4                    36374344           0

# %% [markdown]
# ## PREPARATION

# %%
ethnic = ethnic.astype({"District": str})
staar = staar.astype({"District": str})
peims = peims.astype({"District": str})

# %%
# Padd District numbers with 0's
ethnic['District'] = ethnic['District'].str.zfill(6)
staar['District'] = staar['District'].str.zfill(6)
peims['District'] = peims['District'].str.zfill(6)

# %%
ethnic.head()
ethnic.shape

staar.head()
staar.shape

peims.head()
peims.shape
# Out:
#   District  Percentage of Non-White Students
# 0   001902                          0.145315
# 1   001903                          0.211415
# 2   001904                          0.213158
# 3   001906                          0.268657
# 4   001907                          0.717973
# (1201, 2)
#   District  Total Number of Students  Total Number of Passing Students
# 0   001902                       932                               842
# 1   001903                      1991                              1651
# 2   001904                      1365                              1064
# 3   001906                       569                               420
# 4   001907                      5497                              3274
# (1251, 3)
#   District   Payroll  Professional & Contracted  Supplies & Materials  \
# 0   001902   6025217                    1075904                648206
# 1   001903   9093950                    1514689                784631
# 2   001904   6659596                     927209                937810
# 3   001906   3134475                     373513                408024
# 4   001907  25587063                    5603896               4134969
#
#    Other Operating  Instruction & Transfer  Instructional Resource Media  \
# 0           809559                 4649118                         66490
# 1           303052                 7043892                        117860
# 2           278109                 4611747                         51126
# 3           105878                 2087166                         19990
# 4          1048416                18807861                        167823
#
#    Curriculum/Staff Development  Instructional Leadership  \
# 0                          4986                    270353
# 1                         33175                     66374
# 2                        157830                         0
# 3                             0                      7905
# 4                        535649                   1033275
#
#    Campus Administration  Guidance & Counseling  Social Work  Health Services  \
# 0                 306385                 998314            0            37882
# 1                 574699                 202086            0            33657
# 2                 466345                 199338            0           102385
# 3                 379101                  75235            0            40628
# 4                2201907                1443630       170074           208736
#
#    Transportation  Food Service  Extracurricular  General Administration  \
# 0          293070        287406           413755                  284553
# 1          422887        630202           598484                  558948
# 2           38800        411195           754465                  539512
# 3          148301        257465           210240                  201520
# 4         1442619       2071781          1422648                 1287489
#
#    Plant Maintenance/Operation  Security & Monitoring  Data Processing  \
# 0                       773085                      0           173489
# 1                      1248908                  13530           151120
# 2                      1014501                  45482           409998
# 3                       465549                  10415           118375
# 4                      3937087                 242658          1006175
#
#    Community Services  Regular Program  Gifted & Talented Program  \
# 0                   0          2778638                       3968
# 1                 500          5313722                         93
# 2                   0          3945494                      10154
# 3                   0          1499301                      14498
# 4              394932         15527277                      39671
#
#    Career & Technology Program  Students with Disabilities  \
# 0                       251350                     3005575
# 1                       852319                     1028587
# 2                       552217                      726827
# 3                       164641                      447072
# 4                      1625090                     2422707
#
#    State Compensatory Education  Bilingual Program  High School Allotment  \
# 0                        273747               9599                  40285
# 1                        799037                  0                 101243
# 2                        377013                  0                  59567
# 3                        402415               2706                  48748
# 4                       3147717             231026                 302531
#
#     Pre-K  Athletics Program  Undistributed Program  \
# 0   32890             304174                1858660
# 1       0             339045                3262276
# 2  114404             571388                2445660
# 3   29920                  0                1412589
# 4  923035            1214433               10940857
#
#    Total Program Expenditures  Other Uses
# 0                     8558886       48633
# 1                    11696322      102465
# 2                     8802724         481
# 3                     4021890       53786
# 4                    36374344           0
# (1200, 33)

# %%
df = pd.merge(peims, staar, on=['District'])
df = pd.merge(df, ethnic, on=['District'])

# %%
df['Efficiency'] = df['Total Program Expenditures'] / (df['Total Number of Passing Students'] / df['Total Number of Students'])

# %%
df = df.drop(columns=['Total Program Expenditures',
                      'Total Number of Passing Students',
                      'Total Number of Students',
                      'Percentage of Non-White Students'
                     ])

# %%
df['Efficiency'].describe()
# Out:
# count    1.250000e+03
# mean              inf
# std               NaN
# min      2.257446e+05
# 25%      7.173725e+06
# 50%      1.676200e+07
# 75%      5.623337e+07
# max               inf
# Name: Efficiency, dtype: float64

# %%
df['Efficiency'].quantile(q=.25)
# Out:
# 7173725.125733661

# %%
df_pass = df[df['Efficiency'] <=  df['Efficiency'].quantile(q=.25)]
df_fail = df[df['Efficiency'] >   df['Efficiency'].quantile(q=.25)]

# %%
df_pass.shape
df_fail.shape
# Out:
# (313, 33)
# (937, 33)

# %%
df_pass['Performance'] = 1
df_fail['Performance'] = 0
# Out:
# C:\Users\Dd\AppData\Local\Temp\ipykernel_3092\4042116679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pass['Performance'] = 1
# C:\Users\Dd\AppData\Local\Temp\ipykernel_3092\4042116679.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fail['Performance'] = 0

# %%
df_pass = df_pass.drop(columns=['Efficiency'])
df_fail = df_fail.drop(columns=['Efficiency'])

# %%
df_pass.head()
# Out:
#    District  Payroll  Professional & Contracted  Supplies & Materials  \
# 3    001906  3134475                     373513                408024
# 6    001909  3337495                     368510                316227
# 17   005901  4630369                     597689                606930
# 19   005904  3481271                     405820                437489
# 20   006902  2977900                     500186                288428
#
#     Other Operating  Instruction & Transfer  Instructional Resource Media  \
# 3            105878                 2087166                         19990
# 6            128978                 2593220                         59946
# 17           175785                 3515487                         98748
# 19           174214                 2554924                         41212
# 20           128975                 2097756                         54868
#
#     Curriculum/Staff Development  Instructional Leadership  \
# 3                              0                      7905
# 6                           1387                      1400
# 17                         12416                      5447
# 19                          7951                         0
# 20                         14136                     25890
#
#     Campus Administration  Guidance & Counseling  Social Work  \
# 3                  379101                  75235            0
# 6                  245722                 127860            0
# 17                 265612                 145857            0
# 19                 251616                  53537            0
# 20                 175480                  95848            0
#
#     Health Services  Transportation  Food Service  Extracurricular  \
# 3             40628          148301        257465           210240
# 6             36981           93940        184491           140536
# 17            48352          144273        219839           436803
# 19            59433          129778        204352           353938
# 20             3402           70789        141571           219744
#
#     General Administration  Plant Maintenance/Operation  \
# 3                   201520                       465549
# 6                   247749                       382488
# 17                  295749                       628276
# 19                  318749                       511827
# 20                  387977                       455139
#
#     Security & Monitoring  Data Processing  Community Services  \
# 3                   10415           118375                   0
# 6                    9868            25622                   0
# 17                  43025            27290              123599
# 19                   7977             3500                   0
# 20                    306           152583                   0
#
#     Regular Program  Gifted & Talented Program  Career & Technology Program  \
# 3           1499301                      14498                       164641
# 6           1746364                      10300                       267621
# 17          2556509                      18239                       407573
# 19          1961002                      10052                       295410
# 20          1654362                       9941                       227435
#
#     Students with Disabilities  State Compensatory Education  \
# 3                       447072                        402415
# 6                       384231                        612179
# 17                      583990                        448278
# 19                      274796                        349642
# 20                      224233                        263377
#
#     Bilingual Program  High School Allotment  Pre-K  Athletics Program  \
# 3                2706                  48748  29920                  0
# 6               14196                  31625      0             107301
# 17               3079                  56893  29883             327419
# 19              49596                  52162      0             308249
# 20               2656                  32793  67789             125404
#
#     Undistributed Program  Other Uses  Performance
# 3                 1412589       53786            1
# 6                  977393      208526            1
# 17                1578910       12923            1
# 19                1197885       27531            1
# 20                1287499        8295            1

# %%
df = pd.concat([df_pass, df_fail])

# %%
X = df.drop("Performance", axis=1)
y = df['Performance']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=493, stratify=y)

# %% [markdown]
# ## EXPLORATION

# %%
viz_correlation(df, 'District', 'Payroll', 'Professional & Contracted',
       'Supplies & Materials', 'Other Operating', 'Instruction & Transfer',
       'Instructional Resource Media', 'Curriculum/Staff Development',
       'Instructional Leadership', 'Campus Administration',
       'Guidance & Counseling', 'Social Work', 'Health Services',
       'Transportation', 'Food Service', 'Extracurricular',
       'General Administration', 'Plant Maintenance/Operation',
       'Security & Monitoring', 'Data Processing', 'Community Services',
       'Regular Program', 'Gifted & Talented Program',
       'Career & Technology Program', 'Students with Disabilities',
       'State Compensatory Education', 'Bilingual Program',
       'High School Allotment', 'Pre-K', 'Athletics Program',
       'Undistributed Program', 'Other Uses', 'Performance'
               )

# %%
df.columns
# Out:
# Index(['District', 'Payroll', 'Professional & Contracted',
#        'Supplies & Materials', 'Other Operating', 'Instruction & Transfer',
#        'Instructional Resource Media', 'Curriculum/Staff Development',
#        'Instructional Leadership', 'Campus Administration',
#        'Guidance & Counseling', 'Social Work', 'Health Services',
#        'Transportation', 'Food Service', 'Extracurricular',
#        'General Administration', 'Plant Maintenance/Operation',
#        'Security & Monitoring', 'Data Processing', 'Community Services',
#        'Regular Program', 'Gifted & Talented Program',
#        'Career & Technology Program', 'Students with Disabilities',
#        'State Compensatory Education', 'Bilingual Program',
#        'High School Allotment', 'Pre-K', 'Athletics Program',
#        'Undistributed Program', 'Other Uses', 'Performance'],
#       dtype='object')

# %%
viz_pairplot(df, 'Proficiency: APPROACHES',
                 'Payroll',
                 'Bilingual Program',
                 'Students with Disabilities',
                 'Security & Monitoring',
                 'Gifted & Talented Program',
                 'Instructional Leadership',
                 'Campus Administration',
                 'Transportation'
            )

# %%
df_pass.head()
# Out:
#    District  Payroll  Professional & Contracted  Supplies & Materials  \
# 3    001906  3134475                     373513                408024
# 6    001909  3337495                     368510                316227
# 17   005901  4630369                     597689                606930
# 19   005904  3481271                     405820                437489
# 20   006902  2977900                     500186                288428
#
#     Other Operating  Instruction & Transfer  Instructional Resource Media  \
# 3            105878                 2087166                         19990
# 6            128978                 2593220                         59946
# 17           175785                 3515487                         98748
# 19           174214                 2554924                         41212
# 20           128975                 2097756                         54868
#
#     Curriculum/Staff Development  Instructional Leadership  \
# 3                              0                      7905
# 6                           1387                      1400
# 17                         12416                      5447
# 19                          7951                         0
# 20                         14136                     25890
#
#     Campus Administration  Guidance & Counseling  Social Work  \
# 3                  379101                  75235            0
# 6                  245722                 127860            0
# 17                 265612                 145857            0
# 19                 251616                  53537            0
# 20                 175480                  95848            0
#
#     Health Services  Transportation  Food Service  Extracurricular  \
# 3             40628          148301        257465           210240
# 6             36981           93940        184491           140536
# 17            48352          144273        219839           436803
# 19            59433          129778        204352           353938
# 20             3402           70789        141571           219744
#
#     General Administration  Plant Maintenance/Operation  \
# 3                   201520                       465549
# 6                   247749                       382488
# 17                  295749                       628276
# 19                  318749                       511827
# 20                  387977                       455139
#
#     Security & Monitoring  Data Processing  Community Services  \
# 3                   10415           118375                   0
# 6                    9868            25622                   0
# 17                  43025            27290              123599
# 19                   7977             3500                   0
# 20                    306           152583                   0
#
#     Regular Program  Gifted & Talented Program  Career & Technology Program  \
# 3           1499301                      14498                       164641
# 6           1746364                      10300                       267621
# 17          2556509                      18239                       407573
# 19          1961002                      10052                       295410
# 20          1654362                       9941                       227435
#
#     Students with Disabilities  State Compensatory Education  \
# 3                       447072                        402415
# 6                       384231                        612179
# 17                      583990                        448278
# 19                      274796                        349642
# 20                      224233                        263377
#
#     Bilingual Program  High School Allotment  Pre-K  Athletics Program  \
# 3                2706                  48748  29920                  0
# 6               14196                  31625      0             107301
# 17               3079                  56893  29883             327419
# 19              49596                  52162      0             308249
# 20               2656                  32793  67789             125404
#
#     Undistributed Program  Other Uses  Performance
# 3                 1412589       53786            1
# 6                  977393      208526            1
# 17                1578910       12923            1
# 19                1197885       27531            1
# 20                1287499        8295            1

# %%
loop_levene(df_pass.drop(columns=['District']),
            df_fail.drop(columns=['District']))
# Out:
# 3.567953829125212e-10 - Payroll  -  significant - HETEROGENOUS
# 3.3966367795280845e-09 - Professional & Contracted  -  significant - HETEROGENOUS
# 6.05525474476446e-11 - Supplies & Materials  -  significant - HETEROGENOUS
# 1.3205428100755144e-11 - Other Operating  -  significant - HETEROGENOUS
# 2.531201769352297e-10 - Instruction & Transfer  -  significant - HETEROGENOUS
# 9.115044876053977e-11 - Instructional Resource Media  -  significant - HETEROGENOUS
# 4.2991962234256835e-08 - Curriculum/Staff Development  -  significant - HETEROGENOUS
# 4.425222721952402e-10 - Instructional Leadership  -  significant - HETEROGENOUS
# 2.327706915771739e-09 - Campus Administration  -  significant - HETEROGENOUS
# 3.245224036684085e-10 - Guidance & Counseling  -  significant - HETEROGENOUS
# 9.271163850725978e-06 - Social Work  -  significant - HETEROGENOUS
# 5.391073010950705e-09 - Health Services  -  significant - HETEROGENOUS
# 4.2654021360114094e-10 - Transportation  -  significant - HETEROGENOUS
# 1.7534946995767873e-09 - Food Service  -  significant - HETEROGENOUS
# 3.9947345318095595e-15 - Extracurricular  -  significant - HETEROGENOUS
# 7.392974003718359e-12 - General Administration  -  significant - HETEROGENOUS
# 4.214732343586076e-11 - Plant Maintenance/Operation  -  significant - HETEROGENOUS
# 1.915968835968563e-09 - Security & Monitoring  -  significant - HETEROGENOUS
# 3.6984681668655985e-08 - Data Processing  -  significant - HETEROGENOUS
# 2.3646888196172955e-05 - Community Services  -  significant - HETEROGENOUS
# 2.1927867841788318e-10 - Regular Program  -  significant - HETEROGENOUS
# 6.186088439210616e-06 - Gifted & Talented Program  -  significant - HETEROGENOUS
# 1.6886103344513243e-12 - Career & Technology Program  -  significant - HETEROGENOUS
# 1.403161566429632e-10 - Students with Disabilities  -  significant - HETEROGENOUS
# 7.343364557332235e-08 - State Compensatory Education  -  significant - HETEROGENOUS
# 2.3137775288523026e-05 - Bilingual Program  -  significant - HETEROGENOUS
# 2.8797998204875726e-10 - High School Allotment  -  significant - HETEROGENOUS
# 5.0763783326133755e-06 - Pre-K  -  significant - HETEROGENOUS
# 5.434358466460598e-16 - Athletics Program  -  significant - HETEROGENOUS
# 1.2004695892157573e-10 - Undistributed Program  -  significant - HETEROGENOUS
# 1.6681169431734988e-05 - Other Uses  -  significant - HETEROGENOUS
# nan - Performance  -  significant - HETEROGENOUS
# C:\Users\Dd\OneDrive\Documents\_github\texas-public-schools\v399\lib\site-packages\scipy\stats\_morestats.py:2604: RuntimeWarning: invalid value encountered in double_scalars
#   W = numer / denom

# %%
loop_shapiro(df_pass.drop(columns=['District']))
# Out:
# 1.0816536555324774e-09 - Payroll  -  significant - ABNORMAL
# 1.0006830005220798e-25 - Professional & Contracted  -  significant - ABNORMAL
# 6.570832766783496e-11 - Supplies & Materials  -  significant - ABNORMAL
# 1.709500698280058e-14 - Other Operating  -  significant - ABNORMAL
# 1.5542432618698143e-10 - Instruction & Transfer  -  significant - ABNORMAL
# 2.337097697938695e-18 - Instructional Resource Media  -  significant - ABNORMAL
# 2.6825117277148936e-31 - Curriculum/Staff Development  -  significant - ABNORMAL
# 1.582229502139009e-30 - Instructional Leadership  -  significant - ABNORMAL
# 4.484764170003663e-16 - Campus Administration  -  significant - ABNORMAL
# 2.1212736376378972e-23 - Guidance & Counseling  -  significant - ABNORMAL
# 1.5908700307619132e-35 - Social Work  -  significant - ABNORMAL
# 2.1621142826473966e-19 - Health Services  -  significant - ABNORMAL
# 1.6057521978751765e-10 - Transportation  -  significant - ABNORMAL
# 1.0791894737849361e-06 - Food Service  -  significant - ABNORMAL
# 1.5940315826113245e-19 - Extracurricular  -  significant - ABNORMAL
# 5.352604830477503e-07 - General Administration  -  significant - ABNORMAL
# 2.61925507324956e-12 - Plant Maintenance/Operation  -  significant - ABNORMAL
# 1.1950334367295652e-29 - Security & Monitoring  -  significant - ABNORMAL
# 1.4580806519310686e-14 - Data Processing  -  significant - ABNORMAL
# 3.39371037779431e-32 - Community Services  -  significant - ABNORMAL
# 5.205480682020705e-16 - Regular Program  -  significant - ABNORMAL
# 7.879157701471315e-30 - Gifted & Talented Program  -  significant - ABNORMAL
# 4.0262175646406384e-13 - Career & Technology Program  -  significant - ABNORMAL
# 9.270355813537447e-19 - Students with Disabilities  -  significant - ABNORMAL
# 3.123678260497087e-10 - State Compensatory Education  -  significant - ABNORMAL
# 5.162242951037586e-33 - Bilingual Program  -  significant - ABNORMAL
# 3.8790644751841583e-17 - High School Allotment  -  significant - ABNORMAL
# 8.798668888110903e-34 - Pre-K  -  significant - ABNORMAL
# 2.246154326347782e-22 - Athletics Program  -  significant - ABNORMAL
# 2.594676651312966e-08 - Undistributed Program  -  significant - ABNORMAL
# 1.113013428162725e-33 - Other Uses  -  significant - ABNORMAL
# 1.0 - Performance  -  insignificant - NORMAL
# C:\Users\Dd\OneDrive\Documents\_github\texas-public-schools\v399\lib\site-packages\scipy\stats\_morestats.py:1758: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "

# %%
loop_shapiro(df_fail.drop(columns=['District']))
# Out:
# 0.0 - Payroll  -  significant - ABNORMAL
# 0.0 - Professional & Contracted  -  significant - ABNORMAL
# 0.0 - Supplies & Materials  -  significant - ABNORMAL
# 0.0 - Other Operating  -  significant - ABNORMAL
# 0.0 - Instruction & Transfer  -  significant - ABNORMAL
# 0.0 - Instructional Resource Media  -  significant - ABNORMAL
# 0.0 - Curriculum/Staff Development  -  significant - ABNORMAL
# 0.0 - Instructional Leadership  -  significant - ABNORMAL
# 0.0 - Campus Administration  -  significant - ABNORMAL
# 0.0 - Guidance & Counseling  -  significant - ABNORMAL
# 0.0 - Social Work  -  significant - ABNORMAL
# 0.0 - Health Services  -  significant - ABNORMAL
# 0.0 - Transportation  -  significant - ABNORMAL
# 0.0 - Food Service  -  significant - ABNORMAL
# 2.2420775429197073e-44 - Extracurricular  -  significant - ABNORMAL
# 0.0 - General Administration  -  significant - ABNORMAL
# 0.0 - Plant Maintenance/Operation  -  significant - ABNORMAL
# 0.0 - Security & Monitoring  -  significant - ABNORMAL
# 0.0 - Data Processing  -  significant - ABNORMAL
# 0.0 - Community Services  -  significant - ABNORMAL
# 0.0 - Regular Program  -  significant - ABNORMAL
# 0.0 - Gifted & Talented Program  -  significant - ABNORMAL
# 0.0 - Career & Technology Program  -  significant - ABNORMAL
# 0.0 - Students with Disabilities  -  significant - ABNORMAL
# 0.0 - State Compensatory Education  -  significant - ABNORMAL
# 0.0 - Bilingual Program  -  significant - ABNORMAL
# 0.0 - High School Allotment  -  significant - ABNORMAL
# 0.0 - Pre-K  -  significant - ABNORMAL
# 1.0089348943138683e-43 - Athletics Program  -  significant - ABNORMAL
# 0.0 - Undistributed Program  -  significant - ABNORMAL
# 0.0 - Other Uses  -  significant - ABNORMAL
# 1.0 - Performance  -  insignificant - NORMAL
# C:\Users\Dd\OneDrive\Documents\_github\texas-public-schools\v399\lib\site-packages\scipy\stats\_morestats.py:1758: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "

# %%
loop_mannwhitney(df_pass.drop(columns=['District']),
                 df_fail.drop(columns=['District']))
# Out:
# Statistics=7184.000, p=0.000 - Payroll - DIFFERENT (reject H0)
# Statistics=11836.000, p=0.000 - Professional & Contracted - DIFFERENT (reject H0)
# Statistics=12095.000, p=0.000 - Supplies & Materials - DIFFERENT (reject H0)
# Statistics=13720.000, p=0.000 - Other Operating - DIFFERENT (reject H0)
# Statistics=6986.000, p=0.000 - Instruction & Transfer - DIFFERENT (reject H0)
# Statistics=38670.000, p=0.000 - Instructional Resource Media - DIFFERENT (reject H0)
# Statistics=30301.000, p=0.000 - Curriculum/Staff Development - DIFFERENT (reject H0)
# Statistics=35072.000, p=0.000 - Instructional Leadership - DIFFERENT (reject H0)
# Statistics=7602.500, p=0.000 - Campus Administration - DIFFERENT (reject H0)
# Statistics=15098.500, p=0.000 - Guidance & Counseling - DIFFERENT (reject H0)
# Statistics=90853.000, p=0.000 - Social Work - DIFFERENT (reject H0)
# Statistics=26526.500, p=0.000 - Health Services - DIFFERENT (reject H0)
# Statistics=34375.500, p=0.000 - Transportation - DIFFERENT (reject H0)
# Statistics=14265.000, p=0.000 - Food Service - DIFFERENT (reject H0)
# Statistics=27330.000, p=0.000 - Extracurricular - DIFFERENT (reject H0)
# Statistics=15470.000, p=0.000 - General Administration - DIFFERENT (reject H0)
# Statistics=11640.000, p=0.000 - Plant Maintenance/Operation - DIFFERENT (reject H0)
# Statistics=31524.500, p=0.000 - Security & Monitoring - DIFFERENT (reject H0)
# Statistics=35622.500, p=0.000 - Data Processing - DIFFERENT (reject H0)
# Statistics=75180.000, p=0.000 - Community Services - DIFFERENT (reject H0)
# Statistics=11419.000, p=0.000 - Regular Program - DIFFERENT (reject H0)
# Statistics=40640.500, p=0.000 - Gifted & Talented Program - DIFFERENT (reject H0)
# Statistics=25209.000, p=0.000 - Career & Technology Program - DIFFERENT (reject H0)
# Statistics=11051.000, p=0.000 - Students with Disabilities - DIFFERENT (reject H0)
# Statistics=11333.500, p=0.000 - State Compensatory Education - DIFFERENT (reject H0)
# Statistics=37703.000, p=0.000 - Bilingual Program - DIFFERENT (reject H0)
# Statistics=29816.000, p=0.000 - High School Allotment - DIFFERENT (reject H0)
# Statistics=75977.500, p=0.000 - Pre-K - DIFFERENT (reject H0)
# Statistics=32075.000, p=0.000 - Athletics Program - DIFFERENT (reject H0)
# Statistics=8880.000, p=0.000 - Undistributed Program - DIFFERENT (reject H0)
# Statistics=126549.500, p=0.000 - Other Uses - DIFFERENT (reject H0)
# Statistics=293281.000, p=0.000 - Performance - DIFFERENT (reject H0)

# %%
df.columns
# Out:
# Index(['District', 'Payroll', 'Professional & Contracted',
#        'Supplies & Materials', 'Other Operating', 'Instruction & Transfer',
#        'Instructional Resource Media', 'Curriculum/Staff Development',
#        'Instructional Leadership', 'Campus Administration',
#        'Guidance & Counseling', 'Social Work', 'Health Services',
#        'Transportation', 'Food Service', 'Extracurricular',
#        'General Administration', 'Plant Maintenance/Operation',
#        'Security & Monitoring', 'Data Processing', 'Community Services',
#        'Regular Program', 'Gifted & Talented Program',
#        'Career & Technology Program', 'Students with Disabilities',
#        'State Compensatory Education', 'Bilingual Program',
#        'High School Allotment', 'Pre-K', 'Athletics Program',
#        'Undistributed Program', 'Other Uses', 'Performance'],
#       dtype='object')

# %%
for column in df.columns:
    viz_violin(df, 'Performance', column, 'Performance vs. ' + column)

# %%
stat, p = mannwhitneyu(df_pass['Payroll'], df_fail['Payroll'])
p
# Out:
# 2.3747162505009802e-140

# %%
if p > ALPHA:
    interpretation = 'SAME (fail to reject H0)'
    print('Statistics=%.3f, p=%.3f' % (stat, p) + ' - ' + 'Payroll' + ' - ' + interpretation)
else:
    interpretation = 'DIFFERENT (reject H0)'
    print('Statistics=%.3f, p=%.3f' % (stat, p) + ' - ' + 'Payroll' + ' - ' + interpretation)
# Out:
# Statistics=7184.000, p=0.000 - Payroll - DIFFERENT (reject H0)
